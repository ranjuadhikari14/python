# %%
import numpy as np
import pandas as pd

# %%
dict={
    "name":['ram','shyam','sita','gita'],
    "address":['bharatpur','chitwan','hetauda','gaindakot'],
    "age":[20,30,40,50]
    
    
}

# %%
ab=pd.DataFrame(dict)

# %%
ab.to_csv('excelsheet.csv')
