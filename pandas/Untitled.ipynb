# %%
import numpy as np
import pandas as pd

# %%
dict1={
"name":['ram','shyam','hari'],
"marks":[100,90,95],
"address":['rampur','bharatpur','chitwan']
        
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks    address
# 0    ram    100     rampur
# 1  shyam     90  bharatpur
# 2   hari     95    chitwan

# %%
pd.DataFrame(dict1)
# Out:
#     name  marks    address
# 0    ram    100     rampur
# 1  shyam     90  bharatpur
# 2   hari     95    chitwan

# %%
df.to_csv('excelsheet.csv')
